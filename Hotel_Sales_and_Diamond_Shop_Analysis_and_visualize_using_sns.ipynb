# %%
import seaborn as sns
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
st=sns.load_dataset('tips')

# %%
st.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#relpot - numerical data plotting
#catplot - catagorical data plotting
sns.relplot(x='total_bill', y='tip' , data =st,hue='smoker')

# %%
st['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
  st['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
from numpy.random import randint

# %%
sns.relplot(x='total_bill', y='size' ,kind='line', data =st,hue='smoker')

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint', y='signal',kind='line',data=fmri,label='signal')
plt.legend(loc='right')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
sns.relplot(x='timepoint', y='signal',kind='line',hue='event',style='region', data=fmri,label='signal')
plt.grid()
plt.legend(loc='right')

# %%
dots=sns.load_dataset('dots').query("align=='dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x='time',y='firing_rate',data=dots,kind='line',hue='coherence',style='choice')

# %%
st.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='time',data=st,row='size')

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=st,hue='sex')

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=st,hue='smoker')

# %%
dmd=sns.load_dataset('diamonds')

# %%
dmd.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='color',y='price',kind='boxen',data=dmd)

# %%
sns.catplot(x='color',y='price',kind='boxen',data=dmd,hue='cut')

# %%
sns.relplot(x='cut',y='price',kind='line',data=dmd,style='color')

# %%
sns.catplot(x='color',y='price',kind='box',data=dmd,hue='cut')

# %%
sns.catplot(x='total_bill',y='day',data=st,kind='violin',hue='sex',split=True)

# %%
sns.scatterplot(x="total_bill", y="tip", data=st,hue='sex')
plt.show()

# %%
sns.pairplot(st)

# %%
g=sns.PairGrid(st)
g.map_offdiag(sns.scatterplot)

# %%
sns.regplot(x='total_bill',y='tip',data=st)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill',y='tip',data=st)
